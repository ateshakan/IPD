# %%
#real 1
import numpy as np
def tft(k):
    u=np.array([1,0])
    return u
def rounds(i, func,a,b,func1=tft):
    m=np.array([[2,0],[3,1]])
    n=1
    y1=False
    y2=False
    sum1=0
    sum2=0
    temp1=0
    temp2=0
    k1=100
    k2=100
    s1=a
    if(type(s1))== list :
        k1=s1[1]
        s1=s1[0]
    s2=b
    if (type(s2))==list:
        k2=s2[1]
        s2=s2[0]
    if s1.__name__==func1.__name__:
        y1=True
    if s2.__name__==func1.__name__:
        y2=True   
    
    payoff1, payoff2,u1,u2= func(s1(k1),s2(k2),3,2,1,0)
    sum1=sum1+ payoff1
    sum2=sum2 + payoff2 
    print(u1,u2)
    print(payoff1,payoff2)
    for n in range(2,i+1):
        print(n, "number of round")
        if y1:
            temp1=u2
            u1=temp1
            if y2:
                temp2=u1
                u2=temp2
                payoff1, payoff2,_,_= func(u1,u2,3,2,1,0)
            else:
                payoff1, payoff2,_,u2= func(u1,s2(k2),3,2,1,0)
        elif y2:
            temp2=u1
            u2=temp2
            payoff1,payoff2,u1,_=func(s1(k1),u2,3,2,1,0)
            
        else:payoff1,payoff2,u1,u2= func(s1(k1),s2(k2),n,3,2,1,0)              
        print(u1,u2)    
        sum1=sum1+ payoff1
        sum2=sum2 + payoff2
        print(payoff1,payoff2)
        print(sum1,sum2)
    return sum1, sum2

def strategy(func1,func2,n, T,R,P,S):
    
    u1=func1()
    u2=func2()     
    print(u1,u2)
    m=np.array([[R,S],[T,P]])
    payoff1=np.dot(np.dot(np.transpose(u1),m),u2) 
    payoff2=np.dot(np.dot(np.transpose(u2),m),u1)
    return payoff1, payoff2,u1,u2
def calculate(u1,u2, T,R,P,S):
    m=np.array([[R,S],[T,P]])
    payoff1=np.dot(np.dot(np.transpose(u1),m),u2) 
    payoff2=np.dot(np.dot(np.transpose(u2),m),u1)
    return payoff1, payoff2, u1, u2
def nice_guy(k):
    u=np.array([1,0])
    return u
def bad_guy(k):
    u=np.array([0,1])
    return u
def mainly_good(k):
    test = np.random.choice((0, 1), p=[k/100, 1-k/100])
    if test==0:
        u=np.array([1,0])
    else:
        u=np.array([0,1])
  
    return u    
def mainly_bad(k):
    test = np.random.choice((0, 1), p=[k/100, 1-k/100])
    if test==0:
        u=np.array([1,0])
    else:
        u=np.array([0,1])     
    return u    
def tft(k):
    u=np.array([1,0])
    return u
rounds(50, calculate,[mainly_bad,70],tft)
# Out:
# [1 0] [1 0]
# 2 2
# 2 number of round
# [1 0] [1 0]
# 2 2
# 4 4
# 3 number of round
# [1 0] [1 0]
# 2 2
# 6 6
# 4 number of round
# [1 0] [1 0]
# 2 2
# 8 8
# 5 number of round
# [1 0] [1 0]
# 2 2
# 10 10
# 6 number of round
# [1 0] [1 0]
# 2 2
# 12 12
# 7 number of round
# [1 0] [1 0]
# 2 2
# 14 14
# 8 number of round
# [1 0] [1 0]
# 2 2
# 16 16
# 9 number of round
# [1 0] [1 0]
# 2 2
# 18 18
# 10 number of round
# [1 0] [1 0]
# 2 2
# 20 20
# 11 number of round
# [1 0] [1 0]
# 2 2
# 22 22
# 12 number of round
# [1 0] [1 0]
# 2 2
# 24 24
# 13 number of round
# [1 0] [1 0]
# 2 2
# 26 26
# 14 number of round
# [1 0] [1 0]
# 2 2
# 28 28
# 15 number of round
# [1 0] [1 0]
# 2 2
# 30 30
# 16 number of round
# [0 1] [1 0]
# 3 0
# 33 30
# 17 number of round
# [1 0] [0 1]
# 0 3
# 33 33
# 18 number of round
# [1 0] [1 0]
# 2 2
# 35 35
# 19 number of round
# [1 0] [1 0]
# 2 2
# 37 37
# 20 number of round
# [0 1] [1 0]
# 3 0
# 40 37
# 21 number of round
# [1 0] [0 1]
# 0 3
# 40 40
# 22 number of round
# [1 0] [1 0]
# 2 2
# 42 42
# 23 number of round
# [1 0] [1 0]
# 2 2
# 44 44
# 24 number of round
# [1 0] [1 0]
# 2 2
# 46 46
# 25 number of round
# [0 1] [1 0]
# 3 0
# 49 46
# 26 number of round
# [1 0] [0 1]
# 0 3
# 49 49
# 27 number of round
# [0 1] [1 0]
# 3 0
# 52 49
# 28 number of round
# [0 1] [0 1]
# 1 1
# 53 50
# 29 number of round
# [1 0] [0 1]
# 0 3
# 53 53
# 30 number of round
# [1 0] [1 0]
# 2 2
# 55 55
# 31 number of round
# [1 0] [1 0]
# 2 2
# 57 57
# 32 number of round
# [0 1] [1 0]
# 3 0
# 60 57
# 33 number of round
# [1 0] [0 1]
# 0 3
# 60 60
# 34 number of round
# [1 0] [1 0]
# 2 2
# 62 62
# 35 number of round
# [1 0] [1 0]
# 2 2
# 64 64
# 36 number of round
# [0 1] [1 0]
# 3 0
# 67 64
# 37 number of round
# [1 0] [0 1]
# 0 3
# 67 67
# 38 number of round
# [0 1] [1 0]
# 3 0
# 70 67
# 39 number of round
# [0 1] [0 1]
# 1 1
# 71 68
# 40 number of round
# [1 0] [0 1]
# 0 3
# 71 71
# 41 number of round
# [1 0] [1 0]
# 2 2
# 73 73
# 42 number of round
# [1 0] [1 0]
# 2 2
# 75 75
# 43 number of round
# [1 0] [1 0]
# 2 2
# 77 77
# 44 number of round
# [0 1] [1 0]
# 3 0
# 80 77
# 45 number of round
# [1 0] [0 1]
# 0 3
# 80 80
# 46 number of round
# [0 1] [1 0]
# 3 0
# 83 80
# 47 number of round
# [1 0] [0 1]
# 0 3
# 83 83
# 48 number of round
# [1 0] [1 0]
# 2 2
# 85 85
# 49 number of round
# [0 1] [1 0]
# 3 0
# 88 85
# 50 number of round
# [0 1] [0 1]
# 1 1
# 89 86
# (89, 86)

# %%
#real 2
def rounds(i, func,a,b,func1=tft):
    m=np.array([[2,0],[3,1]])
    n=1
    y1=False
    y2=False
    sum1=0
    sum2=0
    temp1=0
    temp2=0
    s1=a
    s2=b
    if s1.__name__==func1.__name__:
        y1=True
    if s2.__name__==func1.__name__:
        y2=True   
    
    payoff1, payoff2,u1,u2= func(s1(),s2(),3,2,1,0)
    sum1=sum1+ payoff1
    sum2=sum2 + payoff2 
    print(u1,u2)
    print(sum1,sum2)
    #print(payoff1,payoff2)
    for n in range(2,i+1):
        print(n,"number of round")
        if y1:
            temp1=u2
            u1=temp1
            if y2:
                temp2=u1
                u2=temp2
                payoff1, payoff2,_,_= func(u1,u2,3,2,1,0)
            else:
                payoff1, payoff2,_,u2= func(u1,s2(),3,2,1,0)
        elif y2:
            temp2=u1
            u2=temp2
            payoff1,payoff2,u1,_=func(s1(),u2,3,2,1,0)
            
        else:payoff1,payoff2,u1,u2= func(s1(),s2(),3,2,1,0)              
        print(u1,u2)    
        sum1=sum1+ payoff1
        sum2=sum2 + payoff2
        print(payoff1,payoff2)
        print(sum1,sum2)
    return sum1, sum2

def strategy(func1,func2,n, T,R,P,S):
    
    u1=func1()
    u2=func2()     
    print(u1,u2)
    m=np.array([[R,S],[T,P]])
    payoff1=np.dot(np.dot(np.transpose(u1),m),u2) 
    payoff2=np.dot(np.dot(np.transpose(u2),m),u1)
    return payoff1, payoff2,u1,u2
def calculate(u1,u2, T,R,P,S):
    m=np.array([[R,S],[T,P]])
    payoff1=np.dot(np.dot(np.transpose(u1),m),u2) 
    payoff2=np.dot(np.dot(np.transpose(u2),m),u1)
    return payoff1, payoff2, u1, u2
def nice_guy(k=100):
    u=np.array([1,0])
    return u
def bad_guy(k=100):
    u=np.array([0,1])
    return u
def mainly_good(k=70):
    test = np.random.choice((0, 1), p=[k/100, 1-k/100])
    if test==0:
        u=np.array([1,0])
    else:
        u=np.array([0,1])
    print(u,"po")    
    return u    
def mainly_bad(k=70):
    test = np.random.choice((0, 1), p=[k/100, 1-k/100])
    if test==0:
        u=np.array([1,0])
    else:
        u=np.array([0,1])     
    return u    
def tft(k=100):
    u=np.array([1,0])
    return u
#rounds(10, calculate,tft,tft)  
e=[nice_guy,bad_guy,nice_guy]

        
#############################################################################################################################
a=["bad_guy","mainly_good","tft", "nice_guy"]
list1=[]
list2=[]
for n in range(0,len(a)):
    for m in range(0,len(a)):
        if m!=n:
            list1.append(a[n])
            list1.append(a[m])
            m=m+1   
            list2.append(list1) 
            list1=[]   
print(list2)
t_list=[]
for r in range(0,len(list2)):
    print(r,"number of group")
    t_listt=[]
    sum1=0
    sum2=0
    mm=list2[r][0]
    nn=list2[r][1]
    print(mm,nn)
    sum1,sum2=rounds(20, calculate,locals()[mm],locals()[nn])
    print(sum1,sum2, "la")
    t_listt.append(list2[r])
    t_listt.append(sum1)
    t_listt.append(sum2)
    t_list.append(t_listt)

print(t_list)
# Out:
# [['bad_guy', 'mainly_good'], ['bad_guy', 'tft'], ['bad_guy', 'nice_guy'], ['mainly_good', 'bad_guy'], ['mainly_good', 'tft'], ['mainly_good', 'nice_guy'], ['tft', 'bad_guy'], ['tft', 'mainly_good'], ['tft', 'nice_guy'], ['nice_guy', 'bad_guy'], ['nice_guy', 'mainly_good'], ['nice_guy', 'tft']]
# 0 number of group
# bad_guy mainly_good
# [1 0] po
# [0 1] [1 0]
# 3 0
# 2 number of round
# [0 1] po
# [0 1] [0 1]
# 1 1
# 4 1
# 3 number of round
# [1 0] po
# [0 1] [1 0]
# 3 0
# 7 1
# 4 number of round
# [0 1] po
# [0 1] [0 1]
# 1 1
# 8 2
# 5 number of round
# [0 1] po
# [0 1] [0 1]
# 1 1
# 9 3
# 6 number of round
# [1 0] po
# [0 1] [1 0]
# 3 0
# 12 3
# 7 number of round
# [0 1] po
# [0 1] [0 1]
# 1 1
# 13 4
# 8 number of round
# [1 0] po
# [0 1] [1 0]
# 3 0
# 16 4
# 9 number of round
# [1 0] po
# [0 1] [1 0]
# 3 0
# 19 4
# 10 number of round
# [1 0] po
# [0 1] [1 0]
# 3 0
# 22 4
# 11 number of round
# [1 0] po
# [0 1] [1 0]
# 3 0
# 25 4
# 12 number of round
# [1 0] po
# [0 1] [1 0]
# 3 0
# 28 4
# 13 number of round
# [1 0] po
# [0 1] [1 0]
# 3 0
# 31 4
# 14 number of round
# [1 0] po
# [0 1] [1 0]
# 3 0
# 34 4
# 15 number of round
# [1 0] po
# [0 1] [1 0]
# 3 0
# 37 4
# 16 number of round
# [1 0] po
# [0 1] [1 0]
# 3 0
# 40 4
# 17 number of round
# [0 1] po
# [0 1] [0 1]
# 1 1
# 41 5
# 18 number of round
# [0 1] po
# [0 1] [0 1]
# 1 1
# 42 6
# 19 number of round
# [1 0] po
# [0 1] [1 0]
# 3 0
# 45 6
# 20 number of round
# [1 0] po
# [0 1] [1 0]
# 3 0
# 48 6
# 48 6 la
# 1 number of group
# bad_guy tft
# [0 1] [1 0]
# 3 0
# 2 number of round
# [0 1] [0 1]
# 1 1
# 4 1
# 3 number of round
# [0 1] [0 1]
# 1 1
# 5 2
# 4 number of round
# [0 1] [0 1]
# 1 1
# 6 3
# 5 number of round
# [0 1] [0 1]
# 1 1
# 7 4
# 6 number of round
# [0 1] [0 1]
# 1 1
# 8 5
# 7 number of round
# [0 1] [0 1]
# 1 1
# 9 6
# 8 number of round
# [0 1] [0 1]
# 1 1
# 10 7
# 9 number of round
# [0 1] [0 1]
# 1 1
# 11 8
# 10 number of round
# [0 1] [0 1]
# 1 1
# 12 9
# 11 number of round
# [0 1] [0 1]
# 1 1
# 13 10
# 12 number of round
# [0 1] [0 1]
# 1 1
# 14 11
# 13 number of round
# [0 1] [0 1]
# 1 1
# 15 12
# 14 number of round
# [0 1] [0 1]
# 1 1
# 16 13
# 15 number of round
# [0 1] [0 1]
# 1 1
# 17 14
# 16 number of round
# [0 1] [0 1]
# 1 1
# 18 15
# 17 number of round
# [0 1] [0 1]
# 1 1
# 19 16
# 18 number of round
# [0 1] [0 1]
# 1 1
# 20 17
# 19 number of round
# [0 1] [0 1]
# 1 1
# 21 18
# 20 number of round
# [0 1] [0 1]
# 1 1
# 22 19
# 22 19 la
# 2 number of group
# bad_guy nice_guy
# [0 1] [1 0]
# 3 0
# 2 number of round
# [0 1] [1 0]
# 3 0
# 6 0
# 3 number of round
# [0 1] [1 0]
# 3 0
# 9 0
# 4 number of round
# [0 1] [1 0]
# 3 0
# 12 0
# 5 number of round
# [0 1] [1 0]
# 3 0
# 15 0
# 6 number of round
# [0 1] [1 0]
# 3 0
# 18 0
# 7 number of round
# [0 1] [1 0]
# 3 0
# 21 0
# 8 number of round
# [0 1] [1 0]
# 3 0
# 24 0
# 9 number of round
# [0 1] [1 0]
# 3 0
# 27 0
# 10 number of round
# [0 1] [1 0]
# 3 0
# 30 0
# 11 number of round
# [0 1] [1 0]
# 3 0
# 33 0
# 12 number of round
# [0 1] [1 0]
# 3 0
# 36 0
# 13 number of round
# [0 1] [1 0]
# 3 0
# 39 0
# 14 number of round
# [0 1] [1 0]
# 3 0
# 42 0
# 15 number of round
# [0 1] [1 0]
# 3 0
# 45 0
# 16 number of round
# [0 1] [1 0]
# 3 0
# 48 0
# 17 number of round
# [0 1] [1 0]
# 3 0
# 51 0
# 18 number of round
# [0 1] [1 0]
# 3 0
# 54 0
# 19 number of round
# [0 1] [1 0]
# 3 0
# 57 0
# 20 number of round
# [0 1] [1 0]
# 3 0
# 60 0
# 60 0 la
# 3 number of group
# mainly_good bad_guy
# [1 0] po
# [1 0] [0 1]
# 0 3
# 2 number of round
# [0 1] po
# [0 1] [0 1]
# 1 1
# 1 4
# 3 number of round
# [1 0] po
# [1 0] [0 1]
# 0 3
# 1 7
# 4 number of round
# [1 0] po
# [1 0] [0 1]
# 0 3
# 1 10
# 5 number of round
# [1 0] po
# [1 0] [0 1]
# 0 3
# 1 13
# 6 number of round
# [1 0] po
# [1 0] [0 1]
# 0 3
# 1 16
# 7 number of round
# [1 0] po
# [1 0] [0 1]
# 0 3
# 1 19
# 8 number of round
# [1 0] po
# [1 0] [0 1]
# 0 3
# 1 22
# 9 number of round
# [1 0] po
# [1 0] [0 1]
# 0 3
# 1 25
# 10 number of round
# [1 0] po
# [1 0] [0 1]
# 0 3
# 1 28
# 11 number of round
# [1 0] po
# [1 0] [0 1]
# 0 3
# 1 31
# 12 number of round
# [0 1] po
# [0 1] [0 1]
# 1 1
# 2 32
# 13 number of round
# [1 0] po
# [1 0] [0 1]
# 0 3
# 2 35
# 14 number of round
# [0 1] po
# [0 1] [0 1]
# 1 1
# 3 36
# 15 number of round
# [0 1] po
# [0 1] [0 1]
# 1 1
# 4 37
# 16 number of round
# [0 1] po
# [0 1] [0 1]
# 1 1
# 5 38
# 17 number of round
# [1 0] po
# [1 0] [0 1]
# 0 3
# 5 41
# 18 number of round
# [1 0] po
# [1 0] [0 1]
# 0 3
# 5 44
# 19 number of round
# [0 1] po
# [0 1] [0 1]
# 1 1
# 6 45
# 20 number of round
# [1 0] po
# [1 0] [0 1]
# 0 3
# 6 48
# 6 48 la
# 4 number of group
# mainly_good tft
# [0 1] po
# [0 1] [1 0]
# 3 0
# 2 number of round
# [1 0] po
# [1 0] [0 1]
# 0 3
# 3 3
# 3 number of round
# [0 1] po
# [0 1] [1 0]
# 3 0
# 6 3
# 4 number of round
# [1 0] po
# [1 0] [0 1]
# 0 3
# 6 6
# 5 number of round
# [0 1] po
# [0 1] [1 0]
# 3 0
# 9 6
# 6 number of round
# [1 0] po
# [1 0] [0 1]
# 0 3
# 9 9
# 7 number of round
# [0 1] po
# [0 1] [1 0]
# 3 0
# 12 9
# 8 number of round
# [1 0] po
# [1 0] [0 1]
# 0 3
# 12 12
# 9 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 14 14
# 10 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 16 16
# 11 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 18 18
# 12 number of round
# [0 1] po
# [0 1] [1 0]
# 3 0
# 21 18
# 13 number of round
# [1 0] po
# [1 0] [0 1]
# 0 3
# 21 21
# 14 number of round
# [0 1] po
# [0 1] [1 0]
# 3 0
# 24 21
# 15 number of round
# [1 0] po
# [1 0] [0 1]
# 0 3
# 24 24
# 16 number of round
# [0 1] po
# [0 1] [1 0]
# 3 0
# 27 24
# 17 number of round
# [1 0] po
# [1 0] [0 1]
# 0 3
# 27 27
# 18 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 29 29
# 19 number of round
# [0 1] po
# [0 1] [1 0]
# 3 0
# 32 29
# 20 number of round
# [1 0] po
# [1 0] [0 1]
# 0 3
# 32 32
# 32 32 la
# 5 number of group
# mainly_good nice_guy
# [1 0] po
# [1 0] [1 0]
# 2 2
# 2 number of round
# [0 1] po
# [0 1] [1 0]
# 3 0
# 5 2
# 3 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 7 4
# 4 number of round
# [0 1] po
# [0 1] [1 0]
# 3 0
# 10 4
# 5 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 12 6
# 6 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 14 8
# 7 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 16 10
# 8 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 18 12
# 9 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 20 14
# 10 number of round
# [0 1] po
# [0 1] [1 0]
# 3 0
# 23 14
# 11 number of round
# [0 1] po
# [0 1] [1 0]
# 3 0
# 26 14
# 12 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 28 16
# 13 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 30 18
# 14 number of round
# [0 1] po
# [0 1] [1 0]
# 3 0
# 33 18
# 15 number of round
# [0 1] po
# [0 1] [1 0]
# 3 0
# 36 18
# 16 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 38 20
# 17 number of round
# [0 1] po
# [0 1] [1 0]
# 3 0
# 41 20
# 18 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 43 22
# 19 number of round
# [0 1] po
# [0 1] [1 0]
# 3 0
# 46 22
# 20 number of round
# [0 1] po
# [0 1] [1 0]
# 3 0
# 49 22
# 49 22 la
# 6 number of group
# tft bad_guy
# [1 0] [0 1]
# 0 3
# 2 number of round
# [0 1] [0 1]
# 1 1
# 1 4
# 3 number of round
# [0 1] [0 1]
# 1 1
# 2 5
# 4 number of round
# [0 1] [0 1]
# 1 1
# 3 6
# 5 number of round
# [0 1] [0 1]
# 1 1
# 4 7
# 6 number of round
# [0 1] [0 1]
# 1 1
# 5 8
# 7 number of round
# [0 1] [0 1]
# 1 1
# 6 9
# 8 number of round
# [0 1] [0 1]
# 1 1
# 7 10
# 9 number of round
# [0 1] [0 1]
# 1 1
# 8 11
# 10 number of round
# [0 1] [0 1]
# 1 1
# 9 12
# 11 number of round
# [0 1] [0 1]
# 1 1
# 10 13
# 12 number of round
# [0 1] [0 1]
# 1 1
# 11 14
# 13 number of round
# [0 1] [0 1]
# 1 1
# 12 15
# 14 number of round
# [0 1] [0 1]
# 1 1
# 13 16
# 15 number of round
# [0 1] [0 1]
# 1 1
# 14 17
# 16 number of round
# [0 1] [0 1]
# 1 1
# 15 18
# 17 number of round
# [0 1] [0 1]
# 1 1
# 16 19
# 18 number of round
# [0 1] [0 1]
# 1 1
# 17 20
# 19 number of round
# [0 1] [0 1]
# 1 1
# 18 21
# 20 number of round
# [0 1] [0 1]
# 1 1
# 19 22
# 19 22 la
# 7 number of group
# tft mainly_good
# [1 0] po
# [1 0] [1 0]
# 2 2
# 2 number of round
# [0 1] po
# [1 0] [0 1]
# 0 3
# 2 5
# 3 number of round
# [0 1] po
# [0 1] [0 1]
# 1 1
# 3 6
# 4 number of round
# [1 0] po
# [0 1] [1 0]
# 3 0
# 6 6
# 5 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 8 8
# 6 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 10 10
# 7 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 12 12
# 8 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 14 14
# 9 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 16 16
# 10 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 18 18
# 11 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 20 20
# 12 number of round
# [0 1] po
# [1 0] [0 1]
# 0 3
# 20 23
# 13 number of round
# [0 1] po
# [0 1] [0 1]
# 1 1
# 21 24
# 14 number of round
# [0 1] po
# [0 1] [0 1]
# 1 1
# 22 25
# 15 number of round
# [1 0] po
# [0 1] [1 0]
# 3 0
# 25 25
# 16 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 27 27
# 17 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 29 29
# 18 number of round
# [0 1] po
# [1 0] [0 1]
# 0 3
# 29 32
# 19 number of round
# [1 0] po
# [0 1] [1 0]
# 3 0
# 32 32
# 20 number of round
# [0 1] po
# [1 0] [0 1]
# 0 3
# 32 35
# 32 35 la
# 8 number of group
# tft nice_guy
# [1 0] [1 0]
# 2 2
# 2 number of round
# [1 0] [1 0]
# 2 2
# 4 4
# 3 number of round
# [1 0] [1 0]
# 2 2
# 6 6
# 4 number of round
# [1 0] [1 0]
# 2 2
# 8 8
# 5 number of round
# [1 0] [1 0]
# 2 2
# 10 10
# 6 number of round
# [1 0] [1 0]
# 2 2
# 12 12
# 7 number of round
# [1 0] [1 0]
# 2 2
# 14 14
# 8 number of round
# [1 0] [1 0]
# 2 2
# 16 16
# 9 number of round
# [1 0] [1 0]
# 2 2
# 18 18
# 10 number of round
# [1 0] [1 0]
# 2 2
# 20 20
# 11 number of round
# [1 0] [1 0]
# 2 2
# 22 22
# 12 number of round
# [1 0] [1 0]
# 2 2
# 24 24
# 13 number of round
# [1 0] [1 0]
# 2 2
# 26 26
# 14 number of round
# [1 0] [1 0]
# 2 2
# 28 28
# 15 number of round
# [1 0] [1 0]
# 2 2
# 30 30
# 16 number of round
# [1 0] [1 0]
# 2 2
# 32 32
# 17 number of round
# [1 0] [1 0]
# 2 2
# 34 34
# 18 number of round
# [1 0] [1 0]
# 2 2
# 36 36
# 19 number of round
# [1 0] [1 0]
# 2 2
# 38 38
# 20 number of round
# [1 0] [1 0]
# 2 2
# 40 40
# 40 40 la
# 9 number of group
# nice_guy bad_guy
# [1 0] [0 1]
# 0 3
# 2 number of round
# [1 0] [0 1]
# 0 3
# 0 6
# 3 number of round
# [1 0] [0 1]
# 0 3
# 0 9
# 4 number of round
# [1 0] [0 1]
# 0 3
# 0 12
# 5 number of round
# [1 0] [0 1]
# 0 3
# 0 15
# 6 number of round
# [1 0] [0 1]
# 0 3
# 0 18
# 7 number of round
# [1 0] [0 1]
# 0 3
# 0 21
# 8 number of round
# [1 0] [0 1]
# 0 3
# 0 24
# 9 number of round
# [1 0] [0 1]
# 0 3
# 0 27
# 10 number of round
# [1 0] [0 1]
# 0 3
# 0 30
# 11 number of round
# [1 0] [0 1]
# 0 3
# 0 33
# 12 number of round
# [1 0] [0 1]
# 0 3
# 0 36
# 13 number of round
# [1 0] [0 1]
# 0 3
# 0 39
# 14 number of round
# [1 0] [0 1]
# 0 3
# 0 42
# 15 number of round
# [1 0] [0 1]
# 0 3
# 0 45
# 16 number of round
# [1 0] [0 1]
# 0 3
# 0 48
# 17 number of round
# [1 0] [0 1]
# 0 3
# 0 51
# 18 number of round
# [1 0] [0 1]
# 0 3
# 0 54
# 19 number of round
# [1 0] [0 1]
# 0 3
# 0 57
# 20 number of round
# [1 0] [0 1]
# 0 3
# 0 60
# 0 60 la
# 10 number of group
# nice_guy mainly_good
# [0 1] po
# [1 0] [0 1]
# 0 3
# 2 number of round
# [0 1] po
# [1 0] [0 1]
# 0 3
# 0 6
# 3 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 2 8
# 4 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 4 10
# 5 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 6 12
# 6 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 8 14
# 7 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 10 16
# 8 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 12 18
# 9 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 14 20
# 10 number of round
# [0 1] po
# [1 0] [0 1]
# 0 3
# 14 23
# 11 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 16 25
# 12 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 18 27
# 13 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 20 29
# 14 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 22 31
# 15 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 24 33
# 16 number of round
# [0 1] po
# [1 0] [0 1]
# 0 3
# 24 36
# 17 number of round
# [0 1] po
# [1 0] [0 1]
# 0 3
# 24 39
# 18 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 26 41
# 19 number of round
# [1 0] po
# [1 0] [1 0]
# 2 2
# 28 43
# 20 number of round
# [0 1] po
# [1 0] [0 1]
# 0 3
# 28 46
# 28 46 la
# 11 number of group
# nice_guy tft
# [1 0] [1 0]
# 2 2
# 2 number of round
# [1 0] [1 0]
# 2 2
# 4 4
# 3 number of round
# [1 0] [1 0]
# 2 2
# 6 6
# 4 number of round
# [1 0] [1 0]
# 2 2
# 8 8
# 5 number of round
# [1 0] [1 0]
# 2 2
# 10 10
# 6 number of round
# [1 0] [1 0]
# 2 2
# 12 12
# 7 number of round
# [1 0] [1 0]
# 2 2
# 14 14
# 8 number of round
# [1 0] [1 0]
# 2 2
# 16 16
# 9 number of round
# [1 0] [1 0]
# 2 2
# 18 18
# 10 number of round
# [1 0] [1 0]
# 2 2
# 20 20
# 11 number of round
# [1 0] [1 0]
# 2 2
# 22 22
# 12 number of round
# [1 0] [1 0]
# 2 2
# 24 24
# 13 number of round
# [1 0] [1 0]
# 2 2
# 26 26
# 14 number of round
# [1 0] [1 0]
# 2 2
# 28 28
# 15 number of round
# [1 0] [1 0]
# 2 2
# 30 30
# 16 number of round
# [1 0] [1 0]
# 2 2
# 32 32
# 17 number of round
# [1 0] [1 0]
# 2 2
# 34 34
# 18 number of round
# [1 0] [1 0]
# 2 2
# 36 36
# 19 number of round
# [1 0] [1 0]
# 2 2
# 38 38
# 20 number of round
# [1 0] [1 0]
# 2 2
# 40 40
# 40 40 la
# [[['bad_guy', 'mainly_good'], 48, 6], [['bad_guy', 'tft'], 22, 19], [['bad_guy', 'nice_guy'], 60, 0], [['mainly_good', 'bad_guy'], 6, 48], [['mainly_good', 'tft'], 32, 32], [['mainly_good', 'nice_guy'], 49, 22], [['tft', 'bad_guy'], 19, 22], [['tft', 'mainly_good'], 32, 35], [['tft', 'nice_guy'], 40, 40], [['nice_guy', 'bad_guy'], 0, 60], [['nice_guy', 'mainly_good'], 28, 46], [['nice_guy', 'tft'], 40, 40]]

# %%
#real 2
def rounds(i, func,a,b,func1=tft):
    m=np.array([[2,0],[3,1]])
    n=1
    y1=False
    y2=False
    sum1=0
    sum2=0
    temp1=0
    temp2=0
    s1=a
    s2=b
    
    if s1.__name__==func1.__name__:
        y1=True
    if s2.__name__==func1.__name__:
        y2=True   
    
    payoff1, payoff2,u1,u2= func(s1(),s2(),3,2,1,0)
    sum1=sum1+ payoff1
    sum2=sum2 + payoff2 
    print(u1,u2)
    print(sum1,sum2)
    #print(payoff1,payoff2)
    for n in range(2,i+1):
        print(n,"number of round")
        if y1:
            temp1=u2
            u1=temp1
            if y2:
                temp2=u1
                u2=temp2
                payoff1, payoff2,_,_= func(u1,u2,3,2,1,0)
            else:
                payoff1, payoff2,_,u2= func(u1,s2(),3,2,1,0)
        elif y2:
            temp2=u1
            u2=temp2
            payoff1,payoff2,u1,_=func(s1(),u2,3,2,1,0)
            
        else:payoff1,payoff2,u1,u2= func(s1(),s2(),3,2,1,0)              
        print(u1,u2)    
        sum1=sum1+ payoff1
        sum2=sum2 + payoff2
        print(payoff1,payoff2)
        print(sum1,sum2)
    return sum1, sum2

def strategy(func1,func2,n, T,R,P,S):
    
    u1=func1()
    u2=func2()     
    print(u1,u2)
    m=np.array([[R,S],[T,P]])
    payoff1=np.dot(np.dot(np.transpose(u1),m),u2) 
    payoff2=np.dot(np.dot(np.transpose(u2),m),u1)
    return payoff1, payoff2,u1,u2
def calculate(u1,u2, T,R,P,S):
    m=np.array([[R,S],[T,P]])
    payoff1=np.dot(np.dot(np.transpose(u1),m),u2) 
    payoff2=np.dot(np.dot(np.transpose(u2),m),u1)
    return payoff1, payoff2, u1, u2
def nice_guy(k=100):
    u=np.array([1,0])
    return u
def bad_guy(k=100):
    u=np.array([0,1])
    return u
def mainly_good(k=70):
    test = np.random.choice((0, 1), p=[k/100, 1-k/100])
    if test==0:
        u=np.array([1,0])
    else:
        u=np.array([0,1])
    print(u,"po")    
    return u    
def mainly_bad(k=70):
    test = np.random.choice((0, 1), p=[k/100, 1-k/100])
    if test==0:
        u=np.array([1,0])
    else:
        u=np.array([0,1])     
    return u    
def tft(k=100):
    u=np.array([1,0])
    return u
#rounds(10, calculate,tft,tft)  
e=[nice_guy,bad_guy,nice_guy]

        
#############################################################################################################################
a=["bad_guy","mainly_good","tft", "nice_guy"]
list1=[]
list2=[]
for n in range(0,len(a)):
    for m in range(0,len(a)):
        if m!=n:
            list1.append(a[n])
            list1.append(a[m])
            m=m+1   
            list2.append(list1) 
            list1=[]   
print(list2)
t_list=[]
for r in range(0,len(list2)):
    print(r,"number of group")
    t_listt=[]
    sum1=0
    sum2=0
    mm=list2[r][0]
    nn=list2[r][1]
    print(mm,nn)
    sum1,sum2=rounds(20, calculate,locals()[mm],locals()[nn])
    print(sum1,sum2, "la")
    t_listt.append(list2[r])
    t_listt.append(sum1)
    t_listt.append(sum2)
    t_list.append(t_listt)

print(t_list)

# %%
#real 3
import pandas as pd
def rounds(i, func,a,b,func1=tft):
    m=np.array([[2,0],[3,1]])
    n=1
    y1=False
    y2=False
    sum1=0
    sum2=0
    temp1=0
    temp2=0
    s1=a
    s2=b
    if s1.__name__==func1.__name__:
        y1=True
    if s2.__name__==func1.__name__:
        y2=True   
    
    payoff1, payoff2,u1,u2= func(s1(),s2(),3,2,1,0)
    sum1=sum1+ payoff1
    sum2=sum2 + payoff2 
    #print(payoff1,payoff2)
    for n in range(2,i+1):
        if y1:
            temp1=u2
            u1=temp1
            if y2:
                temp2=u1
                u2=temp2
                payoff1, payoff2,_,_= func(u1,u2,3,2,1,0)
            else:
                payoff1, payoff2,_,u2= func(u1,s2(),3,2,1,0)
        elif y2:
            temp2=u1
            u2=temp2
            payoff1,payoff2,u1,_=func(s1(),u2,3,2,1,0)
            
        else:payoff1,payoff2,u1,u2= func(s1(),s2(),3,2,1,0)              
    
        sum1=sum1+ payoff1
        sum2=sum2 + payoff2
    return sum1, sum2

def strategy(func1,func2,n, T,R,P,S):
    
    u1=func1()
    u2=func2()     
    print(u1,u2)
    m=np.array([[R,S],[T,P]])
    payoff1=np.dot(np.dot(np.transpose(u1),m),u2) 
    payoff2=np.dot(np.dot(np.transpose(u2),m),u1)
    return payoff1, payoff2,u1,u2
def calculate(u1,u2, T,R,P,S):
    m=np.array([[R,S],[T,P]])
    payoff1=np.dot(np.dot(np.transpose(u1),m),u2) 
    payoff2=np.dot(np.dot(np.transpose(u2),m),u1)
    return payoff1, payoff2, u1, u2
def nice_guy(k=100):
    u=np.array([1,0])
    return u
def bad_guy(k=100):
    u=np.array([0,1])
    return u
def mainly_good(k=70):
    test = np.random.choice((0, 1), p=[k/100, 1-k/100])
    if test==0:
        u=np.array([1,0])
    else:
        u=np.array([0,1])   
    return u    
def mainly_bad(k=70):
    test = np.random.choice((0, 1), p=[k/100, 1-k/100])
    if test==0:
        u=np.array([1,0])
    else:
        u=np.array([0,1])     
    return u    
def tft(k=100):
    u=np.array([1,0])
    return u
#rounds(10, calculate,tft,tft)  
e=[nice_guy,bad_guy,nice_guy]

        
#############################################################################################################################
a=["bad_guy","mainly_good","tft", "nice_guy"]
list1=[]
list2=[]
for n in range(0,len(a)):
    for m in range(0,len(a)):
        if m!=n:
            list1.append(a[n])
            list1.append(a[m])
            m=m+1   
            list2.append(list1) 
            list1=[]   

t_list=[]
for r in range(0,len(list2)):
    t_listt=[]
    sum1=0
    sum2=0
    mm=list2[r][0]
    nn=list2[r][1]
    sum1,sum2=rounds(20, calculate,locals()[mm],locals()[nn])
    t_listt.append(mm)
    t_listt.append(nn)
    t_listt.append(sum1)
    t_listt.append(sum2)
    t_listt.append(sum1+sum2)
    t_list.append(t_listt)
    

df_rp1 = pd.DataFrame(t_list,columns=['Player1', 'Player2', 'Rp1',"Rp2","Sum"]).sort_values(by=['Sum'],ascending=False)    
print(df_rp1)
tm = list()
for i in range(2):
    tm.append(df_rp1.iloc[i]['Player1'])
    tm.append(df_rp1.iloc[i]['Player2'])

next_round= list(set(tm))
print(next_round)
b=["tft","nice_guy","nice_guy","tft"]
list1=[]
list2=[]
for n in range(0,len(b)):
    for m in range(0,len(b)):
        if m!=n:
            list1.append(b[n])
            list1.append(b[m])
            m=m+1   
            list2.append(list1) 
            list1=[]   

t_list=[]
for r in range(0,len(list2)):
    t_listt=[]
    sum1=0
    sum2=0
    mm=list2[r][0]
    nn=list2[r][1]
    sum1,sum2=rounds(20, calculate,locals()[mm],locals()[nn])
    t_listt.append(mm)
    t_listt.append(nn)
    t_listt.append(sum1)
    t_listt.append(sum2)
    t_listt.append(sum1+sum2)
    t_list.append(t_listt)
    
df_rp2 = pd.DataFrame(t_list,columns=['Player1', 'Player2', 'Rp1',"Rp2","Sum"]).sort_values(by=['Sum'],ascending=False)  
print(df_rp2)
# Out:
#         Player1      Player2  Rp1  Rp2  Sum
# 8           tft     nice_guy   40   40   80
# 11     nice_guy          tft   40   40   80
# 5   mainly_good     nice_guy   44   32   76
# 4   mainly_good          tft   38   35   73
# 10     nice_guy  mainly_good   26   47   73
# 7           tft  mainly_good   32   35   67
# 2       bad_guy     nice_guy   60    0   60
# 9      nice_guy      bad_guy    0   60   60
# 0       bad_guy  mainly_good   54    3   57
# 3   mainly_good      bad_guy    5   50   55
# 1       bad_guy          tft   22   19   41
# 6           tft      bad_guy   19   22   41
# ['nice_guy', 'tft']
#      Player1   Player2  Rp1  Rp2  Sum
# 0        tft  nice_guy   40   40   80
# 1        tft  nice_guy   40   40   80
# 2        tft       tft   40   40   80
# 3   nice_guy       tft   40   40   80
# 4   nice_guy  nice_guy   40   40   80
# 5   nice_guy       tft   40   40   80
# 6   nice_guy       tft   40   40   80
# 7   nice_guy  nice_guy   40   40   80
# 8   nice_guy       tft   40   40   80
# 9        tft       tft   40   40   80
# 10       tft  nice_guy   40   40   80
# 11       tft  nice_guy   40   40   80
